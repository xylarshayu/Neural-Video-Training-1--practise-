# %%
import os
import cv2
import math
import pafy
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from moviepy.editor import *
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split


from tensorflow.python.keras.layers import *
from tensorflow.python.layers import *
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.python.keras.utils.np_utils import to_categorical
from tensorflow.python.keras.callbacks import EarlyStopping

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %%
seed_constant = 99
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
plt.figure(figsize = (30, 30))
all_classes_names = os.listdir("C:/Xylar_Projects/Datasets/UCF50")

random_range = random.sample(range(len(all_classes_names)), 20)

for counter, rand_ind in enumerate(random_range):
    #getting class name
    selected_class_name = all_classes_names[rand_ind]

    #getting list of all vids
    vid_list = os.listdir(f'C:/Xylar_Projects/Datasets/UCF50/{selected_class_name}')

    #randomly selecting a vid
    vid = random.choice(vid_list)

    #reading the vid file
    vid_reader = cv2.VideoCapture(f'C:/Xylar_Projects/Datasets/UCF50/{selected_class_name}/{vid}')

    #Getting first frame of the vid file then closing the vid reader. Then converting bgr frame to rgb
    _, bgr_frame = vid_reader.read()
    vid_reader.release()
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    #adding text {classname} on top of the vid frame
    cv2.putText(rgb_frame, selected_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    #Assigning the Frame to a specific position of a subplot
    plt.subplot(5, 4, counter+1)
    plt.imshow(rgb_frame)
    plt.axis('off')

# %%
dataset_path = "C:/Xylar_Projects/Datasets/UCF50"
classes_list = ["PushUps", "WalkingWithDog"]
model_output_size = len(classes_list)

image_height, image_width = 64, 64
max_images_per_class = 8000

# %%
def frames_extraction(video_path):
    #frames will be stored here 👇
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    """ if (video_reader.isOpened() == False):
        print("Error in opening the video file")
        return
    else:
        print("Video Capture succeeded.") """
    #iterating through video frames
    while True:

        success, frame = video_reader.read()
        if not success:
            break
        resized_frame = cv2.resize(frame, (image_height, image_width))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    
    video_reader.release()
    return frames_list

# %%
def create_dataset():
    temp_features = []
    features = []
    labels = []

    for class_index, class_name in enumerate(classes_list):
        print(f'Extracting Data of Class: {class_name}')

        files_list = os.listdir(os.path.join(dataset_path, class_name))
        for file_name in files_list:
            video_file_path = dataset_path + "/" + class_name + "/" + file_name
            frames = frames_extraction(video_file_path)
            temp_features.extend(frames)
        
        #Adding randomly selected frames to the features list
        features.extend(random.sample(temp_features, max_images_per_class))

        #Adding fixed number of labels to the labels list
        labels.extend([class_index] * max_images_per_class)

        #Emptying temp_features
        temp_features.clear()

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels

# %%
features, labels = create_dataset()
# Out:
# Extracting Data of Class: PushUps
# Extracting Data of Class: WalkingWithDog

# %%
#Converting into one-hot-encoded vectors
encoded_labels = to_categorical(labels)

# %%
features_train, features_test, labels_train, labels_test = train_test_split(features, encoded_labels, test_size = 0.2, shuffle = True, random_state = seed_constant)

# %%
from keras.layers import *

# %%
def create_model():
    model = Sequential()

    model.add(Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu', input_shape = (image_height, image_width, 3)))
    model.add(Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(GlobalAveragePooling2D())
    model.add(Dense(256, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dense(model_output_size, activation = 'softmax'))
    return model
model = create_model()
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])
model_training_history = model.fit(x = features_train, y = labels_train, epochs = 10, batch_size = 4 , shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/50
# 2560/2560 [==============================] - 89s 34ms/step - loss: 0.4983 - accuracy: 0.7601 - val_loss: 0.7386 - val_accuracy: 0.6648
# Epoch 2/50
# 2560/2560 [==============================] - 97s 38ms/step - loss: 0.3477 - accuracy: 0.8511 - val_loss: 0.2682 - val_accuracy: 0.9105
# Epoch 3/50
# 2560/2560 [==============================] - 100s 39ms/step - loss: 0.2765 - accuracy: 0.8831 - val_loss: 0.0588 - val_accuracy: 0.9828
# Epoch 4/50
# 2560/2560 [==============================] - 101s 39ms/step - loss: 0.2255 - accuracy: 0.9059 - val_loss: 0.0089 - val_accuracy: 0.9980
# Epoch 5/50
# 2560/2560 [==============================] - 103s 40ms/step - loss: 0.1833 - accuracy: 0.9230 - val_loss: 0.0296 - val_accuracy: 0.9937
# Epoch 6/50
# 2560/2560 [==============================] - 102s 40ms/step - loss: 0.1685 - accuracy: 0.9285 - val_loss: 0.0438 - val_accuracy: 0.9863
# Epoch 7/50
# ...
